# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\USER\Desktop\code\Flutter\assets\facilities.csv")

# %%
df.columns
# Out:
# Index(['시설명', '시설구분코드', '시설구분명', '업종코드', '업종명', '시설유형코드', '시설유형명', '시설상태값',
#        '도로명우편번호', '도로명주소1명', '도로명주소2명', '우편번호값', '시설주소1명', '시설주소2명', '시설경도',
#        '시설위도', '시설전화번호', '시설홈페이지URL', '시도코드', '시도명', '시군구코드', '시군구명',
#        '시설관리읍면동코드', '시설관리읍면동명', '담당전화번호', '실내외구분명', '생활개방여부', '준공일자', '휴업일자',
#        '운영폐업일자', '국가체육시설여부', '삭제여부'],
#       dtype='object')

# %%
df['시설유형명'].unique()
# Out:
# array(['농구', '체력단련장', '간이운동장', '기타시설', '태권도', '당구장', '무도학원', '유도', '실내',
#        '권투', '검도', '우슈', '합기도', '골프', '스크린', '전천후게이트볼장', '구기체육관', '풋살장',
#        '야구장', '골프연습장', '썰매장', '국궁장', '수영', '복합', '축구', '인공암벽장', '수영장',
#        '생활체육관', '씨름장', '야구', '축구장', '롤러스케이트장', '실외', '종합체육시설', '빙상장',
#        '요트장', '카누장', '승마장', '골프장', '줄넘기', '롤러스케이트', '배드민턴', '테니스장',
#        '파크골프장', '무도장', '기타체육시설(체력단련장)', '자동차경주장', '레슬링', '가상체험 체육시설',
#        '빙상', '육상경기장', '사격장', '투기체육관', '양궁장', '하키장', '스키장', '조정카누장',
#        '사이클경기장', '바이애슬론', '스키점프', '크로스컨트리'], dtype=object)

# %%
df[df['시설유형명']=='무도학원']
# Out:
#                     시설명 시설구분코드 시설구분명 업종코드    업종명 시설유형코드 시설유형명 시설상태값   도로명우편번호  \
# 23            국제댄스스포츠센타      N    신고  N14  무도학원업  N1401  무도학원  정상운영  425907.0
# 38             박봉댄스스튜디오      N    신고  N14  무도학원업  N1401  무도학원  정상운영  461827.0
# 84               한국무도학원      N    신고  N14  무도학원업  N1401  무도학원  정상운영  415831.0
# 346     (사)한국댄스스포츠 교육협회      N    신고  N14  무도학원업  N1401  무도학원  정상운영   17774.0
# 1806      21C 댄스스포츠아카데미      N    신고  N14  무도학원업  N1401  무도학원  정상운영   52566.0
# ...                 ...    ...   ...  ...    ...    ...   ...   ...       ...
# 107682    의정부드림스포츠댄스 학원      N    신고  N14  무도학원업  N1401  무도학원  정상운영   11697.0
# 107729        이종호 댄스스포츠      N    신고  N14  무도학원업  N1401  무도학원  정상운영   32974.0
# 107850      전주스포츠댄스아카데미      N    신고  N14  무도학원업  N1401  무도학원  정상운영   54996.0
# 108414  케이 탑 댄스스포츠 아카데미      N    신고  N14  무도학원업  N1401  무도학원  정상운영   22789.0
# 108526          킹댄스무도학원      N    신고  N14  무도학원업  N1401  무도학원  정상운영   34630.0
#
# ...

# %%
df.isna().sum()
# Out:
# 시설명               0
# 시설구분코드            0
# 시설구분명             0
# 업종코드              0
# 업종명               0
# 시설유형코드            0
# 시설유형명             0
# 시설상태값             0
# 도로명우편번호       23860
# 도로명주소1명       12136
# 도로명주소2명       78993
# 우편번호값         21704
# 시설주소1명        11222
# 시설주소2명        78669
# 시설경도              0
# 시설위도              0
# 시설전화번호        42980
# 시설홈페이지URL    105404
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명           1411
# 시설관리읍면동코드     36389
# 시설관리읍면동명      41902
# 담당전화번호        59833
# 실내외구분명        34096
# 생활개방여부            0
# 준공일자              0
# 휴업일자              0
# 운영폐업일자            0
# 국가체육시설여부          0
# 삭제여부              0
# dtype: int64
